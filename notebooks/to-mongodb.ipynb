# %%
import pandas as pd
from pymongo import MongoClient
pd.set_option('display.max_columns', None)

# %%
FILE_PATH = "../data/houses-for-rent.csv"
ATLAS_URL = "mongodb+srv://conghuynt1999:foWcElkNDeLlDNIX@cluster1.oq1l7.mongodb.net/?retryWrites=false&replicaSet=atlas-5tjaoq-shard-0"
DATABASE_NAME = "chotot"
COLLECTION_NAME = "raw_houses_for_rent"

# %%
houses_df = pd.read_csv(FILE_PATH)
houses_df.head()
# Out:
#        ad_id    list_id      list_time  \
# 0  148983771  109051906  1702006245000
# 1  152808559  112328722  1701933976000
# 2  152043174  111673373  1702110778000
# 3  150969082  110755872  1701743146000
# 4  150055631  109969444  1702115497000
#
#                                              subject  \
# 0           1 PHÒNG NGỦ TÁCH BẾP 45M2, CHO NUÔI PET!
# 1  Căn hộ chung cư saigonLAND hẻm 69 Nguyễn Gia T...
# 2        LAVITA CHARM CHO THUÊ CH 2PN 68M2 CÓ NT ĐẸP
# 3  CH cửa kính Thoáng Mát - Máy giặt riêng Ngay Đ...
# 4  Chính chủ Cho thuê căn hộ Saigon South căn 2PN...
#
#                                                 body     price  \
# 0  CĂN HỘ CAO CẤP 1 PHÒNG NGỦ!__45M2\n✓BAN CÔNG L...   8600000
# 1  Cần cho thuê căn chung cư Saigon Land tại hẻm ...  15000000
# 2  CH LAVITA CHARM 1PN VIEW ĐẸP NGAY GẦN NGÃ TƯ B...   8500000
# 3  CH cửa kính Thoáng Mát - Máy giặt riêng Ngay Đ...   7000000
# 4  - Căn hộ 71m², 75m², 76m² - 2PN + 2WC.\n+ Nội ...  13000000
#
#       price_string   size  rooms  toilets          area_name     region_name  \
# 0  8,6 triệu/tháng   45.0      1      1.0  Thành phố Thủ Đức  Tp Hồ Chí Minh
# 1   15 triệu/tháng  110.0      3      2.0    Quận Bình Thạnh  Tp Hồ Chí Minh
# 2  8,5 triệu/tháng   68.0      2      2.0  Thành phố Thủ Đức  Tp Hồ Chí Minh
# 3    7 triệu/tháng   35.0      1      1.0             Quận 5  Tp Hồ Chí Minh
# 4   13 triệu/tháng   75.0      2      2.0       Huyện Nhà Bè  Tp Hồ Chí Minh
#
#                              ward_name       street_name  deposit  \
# 0         Phường Thảo Điền (Quận 2 cũ)  Nguyễn Văn Hưởng  8600000
# 1                            Phường 25                D2        0
# 2  Phường Trường Thọ (Quận Thủ Đức cũ)              Số 1        0
# 3                             Phường 4    Đường Trần Phú        0
# 4                        Xã Phước Kiển    Nguyễn Hữu Thọ        0
#
#    zero_deposit  longitude   latitude  owner  company_ad        apartment_type
# 0         False  106.72764  10.815886  False        True  Căn hộ dịch vụ, mini
# 1         False  106.71600  10.805900  False       False              Chung cư
# 2         False  106.75830  10.826700  False        True              Chung cư
# 3         False  106.67910  10.762500  False        True              Chung cư
# 4         False  106.71276  10.703870  False        True              Chung cư

# %%
db = MongoClient(ATLAS_URL)[DATABASE_NAME]
# !WARNING: drop collection then create new one
if COLLECTION_NAME in db.list_collection_names():
    db[COLLECTION_NAME].drop()
db.create_collection(COLLECTION_NAME)
# Out:
# Collection(Database(MongoClient(host=['cluster1-shard-00-00.oq1l7.mongodb.net:27017', 'cluster1-shard-00-02.oq1l7.mongodb.net:27017', 'cluster1-shard-00-01.oq1l7.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=False, replicaset='atlas-5tjaoq-shard-0', authsource='admin', tls=True), 'chotot'), 'raw_houses_for_rent')

# %%
db.get_collection(COLLECTION_NAME).insert_many(houses_df.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('657e3c71e288b9cfca1c6104'), ObjectId('657e3c71e288b9cfca1c6105'), ObjectId('657e3c71e288b9cfca1c6106'), ObjectId('657e3c71e288b9cfca1c6107'), ObjectId('657e3c71e288b9cfca1c6108'), ObjectId('657e3c71e288b9cfca1c6109'), ObjectId('657e3c71e288b9cfca1c610a'), ObjectId('657e3c71e288b9cfca1c610b'), ObjectId('657e3c71e288b9cfca1c610c'), ObjectId('657e3c71e288b9cfca1c610d'), ObjectId('657e3c71e288b9cfca1c610e'), ObjectId('657e3c71e288b9cfca1c610f'), ObjectId('657e3c71e288b9cfca1c6110'), ObjectId('657e3c71e288b9cfca1c6111'), ObjectId('657e3c71e288b9cfca1c6112'), ObjectId('657e3c71e288b9cfca1c6113'), ObjectId('657e3c71e288b9cfca1c6114'), ObjectId('657e3c71e288b9cfca1c6115'), ObjectId('657e3c71e288b9cfca1c6116'), ObjectId('657e3c71e288b9cfca1c6117'), ObjectId('657e3c71e288b9cfca1c6118'), ObjectId('657e3c71e288b9cfca1c6119'), ObjectId('657e3c71e288b9cfca1c611a'), ObjectId('657e3c71e288b9cfca1c611b'), ObjectId('657e3c71e288b9cfca1c611c'), ObjectId('657e3c71e288b9cfca1c611d'), ObjectId('657e3c71e288b9cfca1c611e'), ObjectId('657e3c71e288b9cfca1c611f'), ObjectId('657e3c71e288b9cfca1c6120'), ObjectId('657e3c71e288b9cfca1c6121'), ObjectId('657e3c71e288b9cfca1c6122'), ObjectId('657e3c71e288b9cfca1c6123'), ObjectId('657e3c71e288b9cfca1c6124'), ObjectId('657e3c71e288b9cfca1c6125'), ObjectId('657e3c71e288b9cfca1c6126'), ObjectId('657e3c71e288b9cfca1c6127'), ObjectId('657e3c71e288b9cfca1c6128'), ObjectId('657e3c71e288b9cfca1c6129'), ObjectId('657e3c71e288b9cfca1c612a'), ObjectId('657e3c71e288b9cfca1c612b'), ObjectId('657e3c71e288b9cfca1c612c'), ObjectId('657e3c71e288b9cfca1c612d'), ObjectId('657e3c71e288b9cfca1c612e'), ObjectId('657e3c71e288b9cfca1c612f'), ObjectId('657e3c71e288b9cfca1c6130'), ObjectId('657e3c71e288b9cfca1c6131'), ObjectId('657e3c71e288b9cfca1c6132'), ObjectId('657e3c71e288b9cfca1c6133'), ObjectId('657e3c71e288b9cfca1c6134'), ObjectId('657e3c71e288b9cfca1c6135'), ObjectId('657e3c71e288b9cfca1c6136'), ObjectId('657e3c71e288b9cfca1c6137'), ObjectId('657e3c71e288b9cfca1c6138'), ObjectId('657e3c71e288b9cfca1c6139'), ObjectId('657e3c71e288b9cfca1c613a'), ObjectId('657e3c71e288b9cfca1c613b'), ObjectId('657e3c71e288b9cfca1c613c'), ObjectId('657e3c71e288b9cfca1c613d'), ObjectId('657e3c71e288b9cfca1c613e'), ObjectId('657e3c71e288b9cfca1c613f'), ObjectId('657e3c71e288b9cfca1c6140'), ObjectId('657e3c71e288b9cfca1c6141'), ObjectId('657e3c71e288b9cfca1c6142'), ObjectId('657e3c71e288b9cfca1c6143'), ObjectId('657e3c71e288b9cfca1c6144'), ObjectId('657e3c71e288b9cfca1c6145'), ObjectId('657e3c71e288b9cfca1c6146'), ObjectId('657e3c71e288b9cfca1c6147'), ObjectId('657e3c71e288b9cfca1c6148'), ObjectId('657e3c71e288b9cfca1c6149'), ObjectId('657e3c71e288b9cfca1c614a'), ObjectId('657e3c71e288b9cfca1c614b'), ObjectId('657e3c71e288b9cfca1c614c'), ObjectId('657e3c71e288b9cfca1c614d'), ObjectId('657e3c71e288b9cfca1c614e'), ObjectId('657e3c71e288b9cfca1c614f'), ObjectId('657e3c71e288b9cfca1c6150'), ObjectId('657e3c71e288b9cfca1c6151'), ObjectId('657e3c71e288b9cfca1c6152'), ObjectId('657e3c71e288b9cfca1c6153'), ObjectId('657e3c71e288b9cfca1c6154'), ObjectId('657e3c71e288b9cfca1c6155'), ObjectId('657e3c71e288b9cfca1c6156'), ObjectId('657e3c71e288b9cfca1c6157'), ObjectId('657e3c71e288b9cfca1c6158'), ObjectId('657e3c71e288b9cfca1c6159'), ObjectId('657e3c71e288b9cfca1c615a'), ObjectId('657e3c71e288b9cfca1c615b'), ObjectId('657e3c71e288b9cfca1c615c'), ObjectId('657e3c71e288b9cfca1c615d'), ObjectId('657e3c71e288b9cfca1c615e'), ObjectId('657e3c71e288b9cfca1c615f'), ObjectId('657e3c71e288b9cfca1c6160'), ObjectId('657e3c71e288b9cfca1c6161'), ObjectId('657e3c71e288b9cfca1c6162'), ObjectId('657e3c71e288b9cfca1c6163'), ObjectId('657e3c71e288b9cfca1c6164'), ObjectId('657e3c71e288b9cfca1c6165'), ObjectId('657e3c71e288b9cfca1c6166'), ObjectId('657e3c71e288b9cfca1c6167'), ObjectId('657e3c71e288b9cfca1c6168'), ObjectId('657e3c71e288b9cfca1c6169'), ObjectId('657e3c71e288b9cfca1c616a'), ObjectId('657e3c71e288b9cfca1c616b'), ObjectId('657e3c71e288b9cfca1c ...

# %%
list(db.get_collection(COLLECTION_NAME).find().limit(5))
# Out:
# [{'_id': ObjectId('657e3c71e288b9cfca1c6104'),
#   'ad_id': 148983771,
#   'list_id': 109051906,
#   'list_time': 1702006245000,
#   'subject': '1 PHÒNG NGỦ TÁCH BẾP 45M2, CHO NUÔI PET!',
#   'body': 'CĂN HỘ CAO CẤP 1 PHÒNG NGỦ!__45M2\n✓BAN CÔNG LỚN, CHO NUÔI PET ✓\n\n**Vị trí: Nguyễn Văn Hưởng, Thảo Điền, Quận 2\nKhu vực trung tâm, đường lớn không bị ngập\nNằm trong khu an ninh, yên tĩnh!!\n\n+ Full nội thất như hình\n\n+ Ban công lớn\n\n+ Nội thất cao cấp\n\n+ 1PN tách bếp riêng biệt \n\n+ Toà nhà có bảo trì thường xuyên\n\n+ Khu vực an ninh, camera \n\n+ Chỉ tính điện, nước\n\n\nChuyên viên kinh doanh Hifriendz!\n\n____HIFRIENDZ HỖ TRỢ CỌC!___',
#   'price': 8600000,
#   'price_string': '8,6 triệu/tháng',
#   'size': 45.0,
#   'rooms': 1,
#   'toilets': 1.0,
#   'area_name': 'Thành phố Thủ Đức',
#   'region_name': 'Tp Hồ Chí Minh',
#   'ward_name': 'Phường Thảo Điền (Quận 2 cũ)',
#   'street_name': 'Nguyễn Văn Hưởng',
#   'deposit': 8600000,
#   'zero_deposit': False,
#   'longitude': 106.72764,
#   'latitude': 10.8158865,
#   'owner': False,
#   'company_ad': True,
#   'apartment_type': 'Căn hộ dịch vụ, mini'},
#  {'_id': ObjectId('657e3c71e288b9cfca1c6105'),
#   'ad_id': 152808559,
#   'list_id': 112328722,
#   'list_time': 1701933976000,
#   'subject': 'Căn hộ chung cư saigonLAND hẻm 69 Nguyễn Gia Trí (3 phòng ngủ_110m2)',
#   'body': 'Cần cho thuê căn chung cư Saigon Land tại hẻm 69 Nguyễn Gi Trí Phường 25 Bình Thạnh\n- DT: 110m2\n- Gồm 1 phòng khách, phòng bếp, 3 phòng ngủ , 2 toilet, 1 phòng giặt, ban công thoáng mát\n- Vị trí tiếp giáp quận 1 và quận 2 nằm sát bên. Cạnh trường Hutech ngay Điện Biên Phủ\n- Căn hộ nằm ở tầng 15 Thoáng mát\n- Giá thuê 15 triệu',
#   'price': 15000000,
#   'price_string': '15 triệu/tháng',
#   'size': 110.0,
#   'rooms': 3,
#   'toilets': 2.0,
#   'area_name': 'Quận Bình Thạnh',
#   'region_name': 'Tp Hồ Chí Minh',
#   'ward_name': 'Phường 25',
#   'street_name': 'D2',
#   'deposit': 0,
#   'zero_deposit': False,
#   'longitude': 106.716,
#   'latitude': 10.8059,
#   'owner': False,
#   'company_ad': False,
#   'apartment_type': 'Chung cư'},
#  {'_id': ObjectId('657e3c71e288b9cfca1c6106'),
#   'ad_id': 152043174,
#   'list_id': 111673373,
#   'list_time': 1702110778000,
#   'subject': 'LAVITA CHARM CHO THUÊ CH 2PN 68M2 CÓ NT ĐẸP',
#   'body': 'CH LAVITA CHARM 1PN VIEW ĐẸP NGAY GẦN NGÃ TƯ BÌNH THÁI\nCăn 2pn2wc 68m2 giá từ 8.5tr/th\nTiện ích nội khu: Bể bơi, siêu thị và cửa hàng tiện lợi ngay tầng trệt, khu vui chơi cho trẻ em, café trên cao, phòng gym, …\nTiện ích ngoại khu:\n- Bệnh viện Quận Thủ Đưc cách 10 phút đi xe\n- Cách 5 phút để di chuyển đến TT y tế dự phòng phường Trường Thọ\n- Hệ thống trường cấp 1,2,3 chỉ trong bán kính 1km\n- Gần các trường Đại học lớn',
#   'price': 8500000,
#   'price_string': '8,5 triệu/tháng',
#   'size': 68.0,
#   'rooms': 2,
#   'toilets': 2.0,
#   'area_name': 'Thành phố Thủ Đức',
#   'region_name': 'Tp Hồ Chí Minh',
#   'ward_name': 'Phường Trường Thọ (Quận Thủ Đức cũ)',
#   'street_name': 'Số 1',
#   'deposit': 0,
#   'zero_deposit': False,
#   'longitude': 106.7583,
#   'latitude': 10.8267,
#   'owner': False,
#   'company_ad': True,
#   'apartment_type': 'Chung cư'},
#  {'_id': ObjectId('657e3c71e288b9cfca1c6107'),
#   'ad_id': 150969082,
#   'list_id': 110755872,
#   'list_time': 1701743146000,
#   'subject': 'CH cửa kính Thoáng Mát - Máy giặt riêng Ngay ĐH Sư Phạm Q5',
#   'body': 'CH cửa kính Thoáng Mát - Máy giặt riêng Ngay ĐH Sư Phạm Q5\n- Địa chỉ: 87/2A Trần Phú - Phường 4 - Quận 5\n- Ngay Ngã Tư Trần Phú giao Lê Hồng Phong\n- Gần ĐH KHTH, ĐH Sài Gòn, ĐH Sư Phạm\n\nTIỆN ÍCH\nThiết kế hiện đại và hợp lý. Đầy đủ phòng ngủ, phòng khách, bếp, WC trong 1 không gian.\n+ Máy lạnh, Kệ bếp nấu ăn, Tủ quần áo, Bàn ghế \n+ Máy giặt ngay trong phòng tiện nghi giặt giũ.\n+ Ban công thoáng mát, hàng xóm lịch sự, yên tĩnh.\n\nAN NINH:\n_ Nhà được giám sát bằng hệ thống camera 24h.\n_ Khu vực chung được vệ sinh hàng ngày\n_ Ra vào bằng thẻ từ, đảm bảo an toàn và không lo mất mát.\n\nGía thuê chỉ 7Tr/Tháng\n🏢\x08Liên hệ Mai Anh để xem phòng và sở hữu ngay kẻo lỡ nhé!\nCảm ơn bạn đã đọc tin và chúc bạn 1 ngày tốt lành ./.',
#   'price': 7000000,
#   'price_string': '7 triệu/tháng',
#   'size': 35.0,
#   'rooms': 1,
#   'toilets': 1.0,
#   'area_name': 'Quận 5',
#   'region_name': 'Tp Hồ Chí Minh',
#   'ward_name': 'Phường 4',
#   'street_name': 'Đường Trần Phú',
#   'deposit': 0,
#   'zero_deposit': False,
#   'longitude': 106.6791,
#   'latitude': 10.7625,
#   'owner': False,
#   'company_ad': True,
#   'apartment_type': 'Chung cư'},
#  {'_id': ObjectId('657e3c71e288b9cfca1c6108'),
#   'ad_id': 150055631,
#   'list_id': 109969444,
#   'list_time': 1702115497000,
#   'subject': 'Chính chủ Cho thuê căn hộ Saigon South căn 2PN2WC giá chỉ 13tr',
#   'body': '- Căn hộ 71m², 75m², 76m² - 2PN + 2WC.\n+ Nội thất cơ bản: 11tr - 12 triệu/tháng.\n+ Đầy đủ nội thất: 12,5tr - 14 triệu/tháng.\n\n- Căn hộ 95m² - 100m² - 104m² - 3PN + 2WC.\n+ Nội thất cơ bản: 14tr - 15 triệu/tháng.\n+ Đầy đủ nội thất: 16tr - 20 triệu/tháng.\n\n- Giá thuê căn hộ phụ thuộc vào nhiều yếu tố như: Nội thất, view căn hộ, hướng căn hộ.\n- Tình trạng bàn giao: Nhà full nội thất cao cấp, mới 100% vừa bàn giao, có thể dọn vào ở ngay.\n- Căn hộ tầng cao như hình bên dưới.\n\n* Hồ bơi tràn bờ 2200m (mệnh danh là resort trong lòng thành phố) + phòng gym quy mô lớn, công viên trung tâm, khu BBQ...\n* Đơn vị quản lý: Chuyên nghiệp, nhân viên tận tình, thoải mái...\n\n* Khu vực giao thông thuận lợi, 5 phút di chuyển đến Phú Mỹ Hưng, 5 phút đến siêu thị Lotte, 10 phút đến Q. 1, gần SC Vivo City, Crescent Mall, Hồ Bán Nguyệt...',
#   'price': 13000000,
#   'price_string': '13 triệu/tháng',
#   'size': 75.0,
#   'rooms': 2,
#   'toilets': 2.0,
#   'area_name': 'Huyện Nhà Bè',
#   'region_name': 'Tp Hồ Chí Minh',
#   'ward_name': 'Xã Phước Kiển',
#   'street_name': 'Nguyễn Hữu Thọ',
#   'deposit': 0,
#   'zero_deposit': False,
#   'longitude': 106.71276,
#   'latitude': 10.70387,
#   'owner': False,
#   'company_ad': True,
#   'apartment_type': 'Chung cư'}]
