# %%
import pandas as pd
from pymongo import MongoClient
import time
pd.set_option('display.max_columns', None)

# %%
FILE_PATH = "../data/houses-for-sale.csv"
ATLAS_URL = "mongodb+srv://conghuynt1999:foWcElkNDeLlDNIX@cluster1.oq1l7.mongodb.net/?retryWrites=false&replicaSet=atlas-5tjaoq-shard-0"
DATABASE_NAME = "chotot"
COLLECTION_NAME = "hcm_houses_for_sale"

# %%
houses_df = pd.read_csv(FILE_PATH)
houses_df.head()
# Out:
# /var/folders/jv/n7b42hhs6lv5q7vckt3nqvrm0000gn/T/ipykernel_22942/585764610.py:1: DtypeWarning: Columns (0,15,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   houses_df = pd.read_csv(FILE_PATH)
#   phone_hidden  apartment_type  escrow_can_deposit    ward  region  length  \
# 0          NaN             NaN                 2.0  9217.0      13    10.0
# 1          NaN             NaN                 2.0  9226.0      13    10.0
# 2          NaN             NaN                 2.0  9217.0      13     NaN
# 3          NaN             NaN                 2.0  9223.0      13     9.5
# 4          NaN             NaN                 2.0  9218.0      13     NaN
#
#    condition_ad                                     reviewer_image  \
# 0           NaN  https://static.chotot.com/thumbs/admin/9999999...
# 1           NaN  https://static.chotot.com/thumbs/admin/9999999...
# 2           NaN  https://static.chotot.com/thumbs/admin/9999999...
# 3           NaN  https://static.chotot.com/thumbs/admin/9999999...
# 4           NaN  https://static.chotot.com/thumbs/admin/9999999...
#
#         phone                       account_oid  number_of_images  floors  \
# 0  092766****  401d3a2722b3029a60f2d06321874778               9.0     3.0
# 1  093366****  2ba33655e496616002ec75c20ddaf5e8               6.0     2.0
# 2  058518****  1ac98311a851b61e093d13cdf1f2de33               4.0     NaN
# 3  090187****  0ab288b7de0724988a0631cf314d5d28               6.0     NaN
# 4  090135****  b85c01229386d78863ff719ae27e0018               3.0     NaN
#
#    label_campaigns has_video address payment_delivery type  size  \
# 0              NaN       NaN     NaN              NaN    s  32.0
# 1              NaN       NaN     NaN              NaN    s  30.0
# 2              NaN       NaN     NaN              NaN    s  10.0
# 3              NaN       NaN     NaN              NaN    s  33.0
# 4              NaN       NaN     NaN              NaN    s  17.0
#
#    zero_deposit  project_oid  \
# 0         False          NaN
# 1         False          NaN
# 2         False          NaN
# 3         False          NaN
# 4         False          NaN
#
#                                           webp_image  contain_videos  \
# 0  https://cdn.chotot.com/Vdo81ZRCsR_OctWMywFZr3h...             2.0
# 1  https://cdn.chotot.com/lwpW1gYbubNF-m7uz7RkWpS...             2.0
# 2  https://cdn.chotot.com/Euh85xletv0yyh10Oj003uI...             2.0
# 3  https://cdn.chotot.com/dgff7XRz_GSDb-BbIsRg8ey...             2.0
# 4  https://cdn.chotot.com/WqEmMlKkfx2YWphvkPfBdVC...             2.0
#
#    living_size                                avatar  property_status  \
# 0         90.0  https://cdn.chotot.com/uac2/15097873              NaN
# 1         70.0   https://cdn.chotot.com/uac2/1264592              NaN
# 2          NaN  https://cdn.chotot.com/uac2/26372279              NaN
# 3          NaN  https://cdn.chotot.com/uac2/26182525              NaN
# 4        103.0  https://cdn.chotot.com/uac2/17667771              NaN
#
#   area_name videos  region_v2  house_type  owner  rooms  \
# 0    Quận 1     []      13000         3.0  False      3
# 1    Quận 1     []      13000         3.0  False      2
# 2    Quận 1     []      13000         3.0  False      4
# 3    Quận 1     []      13000         3.0  False      3
# 4    Quận 1     []      13000         1.0  False      4
#
#    property_back_condition                                             images  \
# 0                      NaN  ['https://cdn.chotot.com/e2KeIxUm3uXx4-PhCOl-o...
# 1                      NaN  ['https://cdn.chotot.com/luF_zbn5o6NS1iX0Fhrqe...
# 2                      NaN  ['https://cdn.chotot.com/bioAQPE4HDyOf9AOXkwku...
# 3                      NaN  ['https://cdn.chotot.com/QM1co-cGTvQn8iS7h4RQt...
# 4                      NaN  ['https://cdn.chotot.com/Wwav0GSz0thp1zhcP56Ft...
#
#   shop_alias  unitnumber_display image company_logo     state block  \
# 0        NaN                 NaN   NaN          NaN  accepted   NaN
# 1        NaN                 NaN   NaN          NaN  accepted   NaN
# 2        NaN                 NaN   NaN          NaN  accepted   NaN
# 3        NaN                 NaN   NaN          NaN  accepted   NaN
# 4        NaN                 NaN   NaN          NaN  accepted   NaN
#
#    pty_map_modifier                                               body  \
# 0            0.0008  Chính chủ cần bán gấp nhà đường Thạch Thị Than...
# 1            0.0008  📌 BÁN NHÀ Quận 1- Nguyễn Văn Cừ, P.Cầu Kho, Q1...
# 2            0.0008  Diện tích: 40m2\nGiá bán: 1 tỷ 468\nKết cấu: 1...
# 3            0.0008  Giá cực tốt, cần tiền bán gấp nhà Đề Thám, Phư...
# 4            0.0008  chính chủ Bán nhà MT Nguyễn Đình Chiểu, Q.1\n3...
#
#    toilets street_number  floornumber     region_name  \
# 0      4.0           NaN          NaN  Tp Hồ Chí Minh
# 1      1.0           NaN          NaN  Tp Hồ Chí Minh
# 2      NaN           NaN          NaN  Tp Hồ Chí Minh
# 3      4.0           NaN          NaN  Tp Hồ Chí Minh
# 4      5.0           NaN          NaN  Tp Hồ Chí Minh
#
#                                              pty_map shop  \
# 0  https://cdn.chotot.com/admincentre/location/10...  NaN
# 1  https://cdn.chotot.com/admincentre/location/10...  NaN
# 2  https://cdn.chotot.com/admincentre/location/10...  NaN
# 3  https://cdn.chotot.com/admincentre/location/10...  NaN
# 4  https://cdn.chotot.com/admincentre/location/10...  NaN
#
#    property_road_condition  ad_labels  account_id  property_legal_document  \
# 0                      NaN        NaN    15097873                      1.0
# 1                      NaN        NaN     1264592                      1.0
# 2                      NaN        NaN    26372279                      NaN
# 3                      NaN        NaN    26182525                      1.0
# 4                      NaN        NaN    17667771                      NaN
#
#             date              location type_name            ward_name  \
# 0  19 phút trước       10.7901,106.693   Cần bán      Phường Tân Định
# 1  20 phút trước      10.7538,106.6872   Cần bán       Phường Cầu Kho
# 2  35 phút trước      10.7917,106.6931   Cần bán      Phường Tân Định
# 3  55 phút trước  10.763212,106.695915   Cần bán  Phường Cầu Ông Lãnh
# 4  59 phút trước      10.7854,106.6968   Cần bán        Phường Đa Kao
#
#                                              subject  direction  \
# 0  Nhà Q1, Thạch Thị Thanh, 3L, full Nội Thất đẹp...        NaN
# 1                  bán nhà nhìn ra cầu nguyễn văn cừ        6.0
# 2  ĐÁY BẮT GIÁ bán nhà Nguyễn Phi Khanh Q.1 1T2L ...        NaN
# 3  Chính chủ cần bán gấp nhà Đề Thám, Quận 1. Giá...        NaN
# 4  Chính chủ bán nhà Ngang 3m MT Nguyễn Đình Chiể...        1.0
#
#    streetnumber_display  pty_jupiter  company_ad  price_million_per_m2  \
# 0                   NaN          0.0        True            184.375000
# 1                   NaN          0.0        True            183.333333
# 2                   NaN          0.0        True            146.800000
# 3                   NaN          0.0        True            103.030303
# 4                   NaN          0.0        True            529.411765
#
#   reviewer_nickname detail_address  width    list_id  area_v2  \
# 0        Trần Thanh            NaN    3.2  112718747    13096
# 1          An Nhiên  Trần Hưng Ðạo    3.0  112642233    13096
# 2           Bình An            NaN    NaN  112824656    13096
# 3          Tuấn Anh            NaN    3.5  111661713    13096
# 4          Minh Tri            NaN    NaN  112824022    13096
#
#    apartment_feature  landed_type  street_id  \
# 0                NaN          NaN        NaN
# 1                NaN          NaN        NaN
# 2                NaN          NaN        NaN
# 3                NaN          NaN        NaN
# 4                NaN          NaN        NaN
#
#                                      thumbnail_image      ad_id  \
# 0  https://cdn.chotot.com/kKpv7Li0ECMHvkXpoD2gihz...  153261936
# 1  https://cdn.chotot.com/7TQhv1Jsfx9ym50yVnUg4xw...  153172868
# 2  https://cdn.chotot.com/Diwx3L28MI5zFdsAEvYfoyi...  153385154
# 3  https://cdn.chotot.com/_1N7QNHhsWtUlfVm3Yv7cnE...  152029634
# 4  https://cdn.chotot.com/MSZ08bYPeOOJqDfCJBzVvja...  153384434
#
#              street_name account_name unitnumber  projectid  \
# 0  Đường Thạch Thị Thanh    Trần Ngọc        NaN        NaN
# 1      Đường Võ Văn Kiệt       Phương        NaN        NaN
# 2       Nguyễn Phi Khanh     Ngọc Ánh        NaN        NaN
# 3                Đề Thám  Võ Minh Thư        NaN        NaN
# 4      Nguyễn Đình Chiểu   Đỗ Kim Sơn        NaN        NaN
#
#   pty_characteristics  furnishing_sell      list_time       price  category  \
# 0                 NaN              1.0  1703499530998  5900000000      1020
# 1                 [2]              NaN  1703499439901  5500000000      1020
# 2                 NaN              NaN  1703498571000  1468000000      1020
# 3                 [2]              1.0  1703497352000  3400000000      1020
# 4                 NaN              NaN  1703497092000  9000000000      1020
#
#   price_string   latitude  protection_entitlement category_name  \
# 0       5,9 tỷ  10.790100                   False         Nhà ở
# 1       5,5 tỷ  10.753800                   False         Nhà ở
# 2     1,468 tỷ  10.791700                   False         Nhà ở
# 3       3,4 tỷ  10.763212                   False         Nhà ở
# 4         9 tỷ  10.785400                   False         Nhà ở
#
#    balconydirection  area   longitude
# 0               NaN    96  106.693000
# 1               NaN    96  106.687200
# 2               NaN    96  106.693100
# 3               NaN    96  106.695915
# 4               NaN    96  106.696800

# %%
db = MongoClient(ATLAS_URL)[DATABASE_NAME]
# !WARNING: drop collection then create new one
if COLLECTION_NAME in db.list_collection_names():
    db[COLLECTION_NAME].drop()
db.create_collection(COLLECTION_NAME)
# Out:
# Collection(Database(MongoClient(host=['cluster1-shard-00-00.oq1l7.mongodb.net:27017', 'cluster1-shard-00-01.oq1l7.mongodb.net:27017', 'cluster1-shard-00-02.oq1l7.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=False, replicaset='atlas-5tjaoq-shard-0', authsource='admin', tls=True), 'chotot'), 'hcm_houses_for_sale')

# %%
start_time = time.time()
db.get_collection(COLLECTION_NAME).insert_many(houses_df.to_dict("records"))
print(
    f"Finish inserting {len(houses_df)} records in {time.time() - start_time} seconds"
)
# Out:
# Finish inserting 48681 records in 46.06412124633789 seconds

# %%
list(db.get_collection(COLLECTION_NAME).find().limit(5))
# Out:
# [{'_id': ObjectId('65895e36dfa59a9b60f34c1d'),
#   'phone_hidden': nan,
#   'apartment_type': nan,
#   'escrow_can_deposit': 2.0,
#   'ward': 9217.0,
#   'region': 13,
#   'length': 10.0,
#   'condition_ad': nan,
#   'reviewer_image': 'https://static.chotot.com/thumbs/admin/9999999757.png',
#   'phone': '092766****',
#   'account_oid': '401d3a2722b3029a60f2d06321874778',
#   'number_of_images': 9.0,
#   'floors': 3.0,
#   'label_campaigns': nan,
#   'has_video': nan,
#   'address': nan,
#   'payment_delivery': nan,
#   'type': 's',
#   'size': 32.0,
#   'zero_deposit': False,
#   'project_oid': nan,
#   'webp_image': 'https://cdn.chotot.com/Vdo81ZRCsR_OctWMywFZr3hP3XtYB3ovug67eSi_B8Q/preset:listing/plain/924c01184dfd502372ef19b3766888a2-2857386312197726672.webp',
#   'contain_videos': 2.0,
#   'living_size': 90.0,
#   'avatar': 'https://cdn.chotot.com/uac2/15097873',
#   'property_status': nan,
#   'area_name': 'Quận 1',
#   'videos': '[]',
#   'region_v2': 13000,
#   'house_type': 3.0,
#   'owner': False,
#   'rooms': 3,
#   'property_back_condition': nan,
#   'images': "['https://cdn.chotot.com/e2KeIxUm3uXx4-PhCOl-o15tryRKsIca5hMUj-iCyqQ/preset:view/plain/924c01184dfd502372ef19b3766888a2-2857386312197726672.jpg', 'https://cdn.chotot.com/at1QPLU-FzGPWv_0JfK2k1qz6Xo8Mac-IdGbr_NK_Xc/preset:view/plain/6a0470c8ee31a512b18700b84eb84547-2857386336576480615.jpg', 'https://cdn.chotot.com/W65Tic5v9HFWFt1joMmfpj3HMQZjqHx7jLug9NdwYLs/preset:view/plain/98f695f59ec5c868c6fe2c76d08b0955-2857386343143331684.jpg', 'https://cdn.chotot.com/po-iWFemU1mU6S3LjnHRO8Bcja5_hSfWcczX2Lhhk5I/preset:view/plain/79d9c7ad767d1b0ca1f3391062e2d17c-2857386352798982608.jpg', 'https://cdn.chotot.com/_V8eQsx9KxNt2tSB-VCbxWI347WcdArgJ5XTB0yq_3M/preset:view/plain/e15b0e930935e9dd31bb67fa3dbdc00c-2857386359803434852.jpg', 'https://cdn.chotot.com/ko1XYQOFlo0Y9YtnpvG1BN5m8k0RltY0KZvZnoXjVEM/preset:view/plain/bbaff01ba96381bb0add0c37a4922bb5-2857386366681005083.jpg', 'https://cdn.chotot.com/ys1sKfL_fmL7PTMffKGKrpUHT-uKGe1Z_MU-rmwGKtc/preset:view/plain/a891c32f07700d01cbbb6bc2ec857150-2857386374425338320.jpg', 'https://cdn.chotot.com/5kZRY7Yruj2iWIUJlBfo7Cl_EZYTMiWTJ9qh-1gDdIY/preset:view/plain/764222a547b7e365d01242e5f80ce182-2857386405539174244.jpg', 'https://cdn.chotot.com/skA3Jp8WXvSuvaaq_PfEuHFOoo1tQ8PCZmyyzGcbrqM/preset:view/plain/7215d1cb5342aafe7017a02863530673-2857389106762923035.jpg']",
#   'shop_alias': nan,
#   'unitnumber_display': nan,
#   'image': nan,
#   'company_logo': nan,
#   'state': 'accepted',
#   'block': nan,
#   'pty_map_modifier': 0.0008,
#   'body': 'Chính chủ cần bán gấp nhà đường Thạch Thị Thanh, Quận 1, gần công viên Lê Văn Tám, thông ra Võ Thị Sáu, Nguyễn Hữu Cầu, Chợ Tân Định, tiện ích xung quanh cao cấp, đầy đủ, gần Chợ, Trường học, Công viên, Bệnh viện, Nhà thờ, Ăn uống, Thời trang,...\n- Diện tích 3,2m x 10m (DTCN: 27,6 m2), xây dựng 3 lầu, 3 phòng ngủ, thiết kế hiện đại, sang trọng, nội thất toàn đồ cao cấp, mua về xách vali vào ở ngay.\n- Sổ hồng chính chủ, hoàn công đầy đủ\n- Giá bán 5,9 tỷ, thương lượng giá tốt.\nXem nhà vui lòng gọi trước 45 phút',
#   'toilets': 4.0,
#   'street_number': nan,
#   'floornumber': nan,
#   'region_name': 'Tp Hồ Chí Minh',
#   'pty_map': 'https://cdn.chotot.com/admincentre/location/10x790900_106x693800_c.jpg',
#   'shop': nan,
#   'property_road_condition': nan,
#   'ad_labels': nan,
#   'account_id': 15097873,
#   'property_legal_document': 1.0,
#   'date': '19 phút trước',
#   'location': '10.7901,106.693',
#   'type_name': 'Cần bán',
#   'ward_name': 'Phường Tân Định',
#   'subject': 'Nhà Q1, Thạch Thị Thanh, 3L, full Nội Thất đẹp, Bán 5,9 tỷ TL Giá Tốt',
#   'direction': nan,
#   'streetnumber_display': nan,
#   'pty_jupiter': 0.0,
#   'company_ad': True,
#   'price_million_per_m2': 184.375,
#   'reviewer_nickname': 'Trần Thanh',
#   'detail_address': nan,
#   'width': 3.2,
#   'list_id': 112718747,
#   'area_v2': 13096,
#   'apartment_feature': nan,
#   'landed_type': nan,
#   'street_id': nan,
#   'thumbnail_image': 'https://cdn.chotot.com/kKpv7Li0ECMHvkXpoD2gihzS1i8jEmWCmmTPtR6h-8s/preset:listing/plain/924c01184dfd502372ef19b3766888a2-2857386312197726672.jpg',
#   'ad_id': 153261936,
#   'street_name': 'Đường Thạch Thị Thanh',
#   'account_name': 'Trần Ngọc',
#   'unitnumber': nan,
#   'projectid': nan,
#   'pty_characteristics': nan,
#   'furnishing_sell': 1.0,
#   'list_time': 1703499530998,
#   'price': 5900000000,
#   'category': 1020,
#   'price_string': '5,9 tỷ',
#   'latitude': 10.7901,
#   'protection_entitlement': False,
#   'category_name': 'Nhà ở',
#   'balconydirection': nan,
#   'area': 96,
#   'longitude': 106.693},
#  {'_id': ObjectId('65895e36dfa59a9b60f34c1e'),
#   'phone_hidden': nan,
#   'apartment_type': nan,
#   'escrow_can_deposit': 2.0,
#   'ward': 9226.0,
#   'region': 13,
#   'length': 10.0,
#   'condition_ad': nan,
#   'reviewer_image': 'https://static.chotot.com/thumbs/admin/9999999725.png',
#   'phone': '093366****',
#   'account_oid': '2ba33655e496616002ec75c20ddaf5e8',
#   'number_of_images': 6.0,
#   'floors': 2.0,
#   'label_campaigns': nan,
#   'has_video': nan,
#   'address': nan,
#   'payment_delivery': nan,
#   'type': 's',
#   'size': 30.0,
#   'zero_deposit': False,
#   'project_oid': nan,
#   'webp_image': 'https://cdn.chotot.com/lwpW1gYbubNF-m7uz7RkWpSXW_-9i2I-E7IGaFNWjxY/preset:listing/plain/fca94cc036eca737f7f46cab41ccaa73-2857035294304167920.webp',
#   'contain_videos': 2.0,
#   'living_size': 70.0,
#   'avatar': 'https://cdn.chotot.com/uac2/1264592',
#   'property_status': nan,
#   'area_name': 'Quận 1',
#   'videos': '[]',
#   'region_v2': 13000,
#   'house_type': 3.0,
#   'owner': False,
#   'rooms': 2,
#   'property_back_condition': nan,
#   'images': "['https://cdn.chotot.com/luF_zbn5o6NS1iX0Fhrqe32MWa3oj-bHpL_4YdBpmc4/preset:view/plain/fca94cc036eca737f7f46cab41ccaa73-2857035294304167920.jpg', 'https://cdn.chotot.com/8sa-K8reSUwHDXA-Nu00dmq63p9MOAhKg1Hb626sMcc/preset:view/plain/f8103e6a279e0dcc57682699855febc8-2857035323010246640.jpg', 'https://cdn.chotot.com/T5s9a6cA-FMEcDx8zIg1tOf5_GOyysNT-0N5ban8b9U/preset:view/plain/716c5e3373f05aa1c29732199e8fb7a1-2857035323353146543.jpg', 'https://cdn.chotot.com/97J-Y8cC9g-hGa34ufJRmFVZ0Qb4RBYP5Cz0qCFYBJI/preset:view/plain/df243e1a6f442e4b6079c0a45a0e8abc-2857035323173537893.jpg', 'https://cdn.chotot.com/DTHl9zuEwnSNeZQhPLYS1WRZ5omwINMKrGddqKuvMnc/preset:view/plain/5b776ed0eaabd8aac49ab6b56d5a8672-2857035323170263394.jpg', 'https://cdn.chotot.com/RxwIedhlNUfoyLjLtPtWw3uid3ncsSz5-RxDupfJads/preset:view/plain/36322c1f918a4acfc3d28871a9a6cf68-2857035323176370346.jpg']",
#   'shop_alias': nan,
#   'unitnumber_display': nan,
#   'image': nan,
#   'company_logo': nan,
#   'state': 'accepted',
#   'block': nan,
#   'pty_map_modifier': 0.0008,
#   'body': '📌 BÁN NHÀ Quận 1- Nguyễn Văn Cừ, P.Cầu Kho, Q1\nDiện tích: 3 x 10 ( 1 trệt, 1 lầu, 1 gác nhỏ, 2PN, 1wc )\n\n-Vị trí : nhìn ra cầu Nguyễn Văn Cừ\n\nGía bán 5,5 tỷ. Sổ hồng đầy đủ',
#   'toilets': 1.0,
#   'street_number': nan,
#   'floornumber': nan,
#   'region_name': 'Tp Hồ Chí Minh',
#   'pty_map': 'https://cdn.chotot.com/admincentre/location/10x754600_106x688000_c.jpg',
#   'shop': nan,
#   'property_road_condition': nan,
#   'ad_labels': nan,
#   'account_id': 1264592,
#   'property_legal_document': 1.0,
#   'date': '20 phút trước',
#   'location': '10.7538,106.6872',
#   'type_name': 'Cần bán',
#   'ward_name': 'Phường Cầu Kho',
#   'subject': 'bán nhà nhìn ra cầu nguyễn văn cừ',
#   'direction': 6.0,
#   'streetnumber_display': nan,
#   'pty_jupiter': 0.0,
#   'company_ad': True,
#   'price_million_per_m2': 183.33333333333331,
#   'reviewer_nickname': 'An Nhiên',
#   'detail_address': 'Trần Hưng Ðạo',
#   'width': 3.0,
#   'list_id': 112642233,
#   'area_v2': 13096,
#   'apartment_feature': nan,
#   'landed_type': nan,
#   'street_id': nan,
#   'thumbnail_image': 'https://cdn.chotot.com/7TQhv1Jsfx9ym50yVnUg4xwr1ry-KAyr_1bGW9ijH90/preset:listing/plain/fca94cc036eca737f7f46cab41ccaa73-2857035294304167920.jpg',
#   'ad_id': 153172868,
#   'street_name': 'Đường Võ Văn Kiệt',
#   'account_name': 'Phương',
#   'unitnumber': nan,
#   'projectid': nan,
#   'pty_characteristics': '[2]',
#   'furnishing_sell': nan,
#   'list_time': 1703499439901,
#   'price': 5500000000,
#   'category': 1020,
#   'price_string': '5,5 tỷ',
#   'latitude': 10.7538,
#   'protection_entitlement': False,
#   'category_name': 'Nhà ở',
#   'balconydirection': nan,
#   'area': 96,
#   'longitude': 106.6872},
#  {'_id': ObjectId('65895e36dfa59a9b60f34c1f'),
#   'phone_hidden': nan,
#   'apartment_type': nan,
#   'escrow_can_deposit': 2.0,
#   'ward': 9217.0,
#   'region': 13,
#   'length': nan,
#   'condition_ad': nan,
#   'reviewer_image': 'https://static.chotot.com/thumbs/admin/9999999918.png',
#   'phone': '058518****',
#   'account_oid': '1ac98311a851b61e093d13cdf1f2de33',
#   'number_of_images': 4.0,
#   'floors': nan,
#   'label_campaigns': nan,
#   'has_video': nan,
#   'address': nan,
#   'payment_delivery': nan,
#   'type': 's',
#   'size': 10.0,
#   'zero_deposit': False,
#   'project_oid': nan,
#   'webp_image': 'https://cdn.chotot.com/Euh85xletv0yyh10Oj003uIOErdvRpWEUURki3XTsOM/preset:listing/plain/3e4978e05a5be3e8a49651aa970a0984-2857995884188586821.webp',
#   'contain_videos': 2.0,
#   'living_size': nan,
#   'avatar': 'https://cdn.chotot.com/uac2/26372279',
#   'property_status': nan,
#   'area_name': 'Quận 1',
#   'videos': '[]',
#   'region_v2': 13000,
#   'house_type': 3.0,
#   'owner': False,
#   'rooms': 4,
#   'property_back_condition': nan,
#   'images': "['https://cdn.chotot.com/bioAQPE4HDyOf9AOXkwkuSR5Bn-t6eEUoFjHgdVh6HA/preset:view/plain/3e4978e05a5be3e8a49651aa970a0984-2857995884188586821.jpg', 'https://cdn.chotot.com/FJVmEDf6afaVpijYxGOrMWXm2HNuhdUCZ7pcXPPt7ZE/preset:view/plain/1f377aedc2369b3e7db877e8c102ab39-2857995890160014573.jpg', 'https://cdn.chotot.com/xSGvCV0OvVoYX3yVTCiD9R2ztvECf1uXSi286UXGt5A/preset:view/plain/4ffbcc9142d71f0d052468f9a89a15f3-2857995899488455738.jpg', 'https://cdn.chotot.com/3dyBL_733MvqzLo82ETMgc0zBdtPMJHh7LDpgZWa2fU/preset:view/plain/6e86acc7ffc8190917b496cd83553e3a-2857995906989544261.jpg']",
#   'shop_alias': nan,
#   'unitnumber_display': nan,
#   'image': nan,
#   'company_logo': nan,
#   'state': 'accepted',
#   'block': nan,
#   'pty_map_modifier': 0.0008,
#   'body': "Diện tích: 40m2\nGiá bán: 1 tỷ 468\nKết cấu: 1 trệt 2 lầu gồm 4pn5wc và sân thượng\nĐường 5m, ô tô quay đầu, đường thông\nĐi ra sân bay, bến xe khoảng 10'\nGàn công viên Lê Văn Tám thuận tiện tập thể dục chạy bộ \nKhu dân cư an ninh\nSổ hồng riêng chính chủ\nHỗ trợ vay ngân hàng 50-70%",
#   'toilets': nan,
#   'street_number': nan,
#   'floornumber': nan,
#   'region_name': 'Tp Hồ Chí Minh',
#   'pty_map': 'https://cdn.chotot.com/admincentre/location/10x792500_106x693900_c.jpg',
#   'shop': nan,
#   'property_road_condition': nan,
#   'ad_labels': nan,
#   'account_id': 26372279,
#   'property_legal_document': nan,
#   'date': '35 phút trước',
#   'location': '10.7917,106.6931',
#   'type_name': 'Cần bán',
#   'ward_name': 'Phường Tân Định',
#   'subject': 'ĐÁY BẮT GIÁ bán nhà Nguyễn Phi Khanh Q.1 1T2L 4PN5WC 40m² 1ty468 SHRCC',
#   'direction': nan,
#   'streetnumber_display': nan,
#   'pty_jupiter': 0.0,
#   'company_ad': True,
#   'price_million_per_m2': 146.8,
#   'reviewer_nickname': 'Bình An',
#   'detail_address': nan,
#   'width': nan,
#   'list_id': 112824656,
#   'area_v2': 13096,
#   'apartment_feature': nan,
#   'landed_type': nan,
#   'street_id': nan,
#   'thumbnail_image': 'https://cdn.chotot.com/Diwx3L28MI5zFdsAEvYfoyinAf57cQCPRyBTcT982fk/preset:listing/plain/3e4978e05a5be3e8a49651aa970a0984-2857995884188586821.jpg',
#   'ad_id': 153385154,
#   'street_name': 'Nguyễn Phi Khanh',
#   'account_name': 'Ngọc Ánh',
#   'unitnumber': nan,
#   'projectid': nan,
#   'pty_characteristics': nan,
#   'furnishing_sell': nan,
#   'list_time': 1703498571000,
#   'price': 1468000000,
#   'category': 1020,
#   'price_string': '1,468 tỷ',
#   'latitude': 10.7917,
#   'protection_entitlement': False,
#   'category_name': 'Nhà ở',
#   'balconydirection': nan,
#   'area': 96,
#   'longitude': 106.6931},
#  {'_id': ObjectId('65895e36dfa59a9b60f34c20'),
#   'phone_hidden': nan,
#   'apartment_type': nan,
#   'escrow_can_deposit': 2.0,
#   'ward': 9223.0,
#   'region': 13,
#   'length': 9.5,
#   'condition_ad': nan,
#   'reviewer_image': 'https://static.chotot.com/thumbs/admin/9999999849.png',
#   'phone': '090187****',
#   'account_oid': '0ab288b7de0724988a0631cf314d5d28',
#   'number_of_images': 6.0,
#   'floors': nan,
#   'label_campaigns': nan,
#   'has_video': nan,
#   'address': nan,
#   'payment_delivery': nan,
#   'type': 's',
#   'size': 33.0,
#   'zero_deposit': False,
#   'project_oid': nan,
#   'webp_image': 'https://cdn.chotot.com/dgff7XRz_GSDb-BbIsRg8eyqQdM6LMQt19QGOZluetM/preset:listing/plain/5e8b10644fc65f378da4cf808f12afa9-2852003039881413510.webp',
#   'contain_videos': 2.0,
#   'living_size': nan,
#   'avatar': 'https://cdn.chotot.com/uac2/26182525',
#   'property_status': nan,
#   'area_name': 'Quận 1',
#   'videos': '[]',
#   'region_v2': 13000,
#   'house_type': 3.0,
#   'owner': False,
#   'rooms': 3,
#   'property_back_condition': nan,
#   'images': "['https://cdn.chotot.com/QM1co-cGTvQn8iS7h4RQtpPzxurjwxC3vnuu5bEqS1o/preset:view/plain/5e8b10644fc65f378da4cf808f12afa9-2852003039881413510.jpg', 'https://cdn.chotot.com/Pw5PqdeDotxRSXts_34KryMt3w_PzzC9mQPKuLIlSyA/preset:view/plain/14fded8bbe2cc466c340b65c90ef8744-2852003039327970277.jpg', 'https://cdn.chotot.com/iz0WNTgLaWVJFMkIP0BYl5XqKwbVoXFmGrOggpjdX7Q/preset:view/plain/0e756de9efe752d40b224566da38c7af-2852003039535985146.jpg', 'https://cdn.chotot.com/RLLJpV8UZ7P1l57OwOVXq9c1EpDFSyB3HKZMui-lxwo/preset:view/plain/a54505513675c182261b0dde259c5cc8-2852003039705944952.jpg', 'https://cdn.chotot.com/tWFPOLaKzx6RljFz6oor0DxA5qkaj_9VNhth11ZitsI/preset:view/plain/36ca4db8d6f63f0dc7ccbc44a0a87fa5-2852003039465728102.jpg', 'https://cdn.chotot.com/CKeO6US_CEGO1Z72O5yXzCx8PrVflwAMhGpVkyKN1Vw/preset:view/plain/8145890d42abb9f9cbbc5bdaa7d33028-2852003040085638416.jpg']",
#   'shop_alias': nan,
#   'unitnumber_display': nan,
#   'image': nan,
#   'company_logo': nan,
#   'state': 'accepted',
#   'block': nan,
#   'pty_map_modifier': 0.0008,
#   'body': 'Giá cực tốt, cần tiền bán gấp nhà Đề Thám, Phường Cầu Ông Lãnh, Quận 1\n\n* DT 3.5m x 9.5m - DTCN 33m²\n\n* Kết cấu 1 trệt, 1 lầu, sân thượng. Gồm: Phòng thờ, phòng khách lớn, 3 phòng ngủ, 4WC.\n\n* Tọa lạc vị trí đắc địa, tiện kinh doanh đa ngành nghề, di chuyển thuận tiện ra nhiều hướng.\n\n* Gần: Trường điểm của quận: Trường mầm non, cấp 1 - 2 - 3, trường quốc tế, UBND, Bệnh Viện , Chợ, Siêu thị, Công Viên,...\n\n* Khu dân cư an ninh, sạch sẽ, hàng xóm thân thiện. Thích hợp mua ở hoặc kinh doanh, mở văn phòng, cho thuê,\n\n* Giá: chỉ 3 tỷ 400 triệu',
#   'toilets': 4.0,
#   'street_number': nan,
#   'floornumber': nan,
#   'region_name': 'Tp Hồ Chí Minh',
#   'pty_map': 'https://cdn.chotot.com/admincentre/location/10x764012_106x696715_c.jpg',
#   'shop': nan,
#   'property_road_condition': nan,
#   'ad_labels': nan,
#   'account_id': 26182525,
#   'property_legal_document': 1.0,
#   'date': '55 phút trước',
#   'location': '10.763212,106.695915',
#   'type_name': 'Cần bán',
#   'ward_name': 'Phường Cầu Ông Lãnh',
#   'subject': 'Chính chủ cần bán gấp nhà Đề Thám, Quận 1. Giá 2 tỷ 600 triệu',
#   'direction': nan,
#   'streetnumber_display': nan,
#   'pty_jupiter': 0.0,
#   'company_ad': True,
#   'price_million_per_m2': 103.03030303030305,
#   'reviewer_nickname': 'Tuấn Anh',
#   'detail_address': nan,
#   'width': 3.5,
#   'list_id': 111661713,
#   'area_v2': 13096,
#   'apartment_feature': nan,
#   'landed_type': nan,
#   'street_id': nan,
#   'thumbnail_image': 'https://cdn.chotot.com/_1N7QNHhsWtUlfVm3Yv7cnEJk_Yy8Cc8Xrq34iLU8UY/preset:listing/plain/5e8b10644fc65f378da4cf808f12afa9-2852003039881413510.jpg',
#   'ad_id': 152029634,
#   'street_name': 'Đề Thám',
#   'account_name': 'Võ Minh Thư',
#   'unitnumber': nan,
#   'projectid': nan,
#   'pty_characteristics': '[2]',
#   'furnishing_sell': 1.0,
#   'list_time': 1703497352000,
#   'price': 3400000000,
#   'category': 1020,
#   'price_string': '3,4 tỷ',
#   'latitude': 10.763212,
#   'protection_entitlement': False,
#   'category_name': 'Nhà ở',
#   'balconydirection': nan,
#   'area': 96,
#   'longitude': 106.695915},
#  {'_id': ObjectId('65895e36dfa59a9b60f34c21'),
#   'phone_hidden': nan,
#   'apartment_type': nan,
#   'escrow_can_deposit': 2.0,
#   'ward': 9218.0,
#   'region': 13,
#   'length': nan,
#   'condition_ad': nan,
#   'reviewer_image': 'https://static.chotot.com/thumbs/admin/9999999715.png',
#   'phone': '090135****',
#   'account_oid': 'b85c01229386d78863ff719ae27e0018',
#   'number_of_images': 3.0,
#   'floors': nan,
#   'label_campaigns': nan,
#   'has_video': nan,
#   'address': nan,
#   'payment_delivery': nan,
#   'type': 's',
#   'size': 17.0,
#   'zero_deposit': False,
#   'project_oid': nan,
#   'webp_image': 'https://cdn.chotot.com/WqEmMlKkfx2YWphvkPfBdVCOp7iUabuJYW3VcUMkM6s/preset:listing/plain/bbd55d06ca58d49940df7fe58b351c9b-2857993845737569899.webp',
#   'contain_videos': 2.0,
#   'living_size': 103.0,
#   'avatar': 'https://cdn.chotot.com/uac2/17667771',
#   'property_status': nan,
#   'area_name': 'Quận 1',
#   'videos': '[]',
#   'region_v2': 13000,
#   'house_type': 1.0,
#   'owner': False,
#   'rooms': 4,
#   'property_back_condition': nan,
#   'images': "['https://cdn.chotot.com/Wwav0GSz0thp1zhcP56FtrYexdPVPcxWVC32NqvqMBs/preset:view/plain/bbd55d06ca58d49940df7fe58b351c9b-2857993845737569899.jpg', 'https://cdn.chotot.com/0VEvGOPLhN_ncwwNp30cyyPA5SQMiDjAoOa7F4rRsuY/preset:view/plain/ec9108c97628aec365a9430bfccc9051-2857993847075402037.jpg', 'https://cdn.chotot.com/B-z7IDndHIAMGh1EaO_ofcdjoggl-Ciebx4w6V-jmzQ/preset:view/plain/704af9f1049461437f397a5c63a685b1-2857993847307531280.jpg']",
#   'shop_alias': nan,
#   'unitnumber_display': nan,
#   'image': nan,
#   'company_logo': nan,
#   'state': 'accepted',
#   'block': nan,
#   'pty_map_modifier': 0.0008,
#   'body': 'chính chủ Bán nhà MT Nguyễn Đình Chiểu, Q.1\n3x5.5m \n5 Lầu\nVị trí con đường 2 chiều xe hơi thích hợp kinh doanh, tập hợp nhiều văn phòng\n9 Tỷ TL cho khách thiện chí\nXem nhà báo trước 30p, cảm ơn',
#   'toilets': 5.0,
#   'street_number': nan,
#   'floornumber': nan,
#   'region_name': 'Tp Hồ Chí Minh',
#   'pty_map': 'https://cdn.chotot.com/admincentre/location/10x786200_106x697600_c.jpg',
#   'shop': nan,
#   'property_road_condition': nan,
#   'ad_labels': nan,
#   'account_id': 17667771,
#   'property_legal_document': nan,
#   'date': '59 phút trước',
#   'location': '10.7854,106.6968',
#   'type_name': 'Cần bán',
#   'ward_name': 'Phường Đa Kao',
#   'subject': 'Chính chủ bán nhà Ngang 3m MT Nguyễn Đình Chiểu Q1 9 TỷTL',
#   'direction': 1.0,
#   'streetnumber_display': nan,
#   'pty_jupiter': 0.0,
#   'company_ad': True,
#   'price_million_per_m2': 529.4117647058823,
#   'reviewer_nickname': 'Minh Tri',
#   'detail_address': nan,
#   'width': nan,
#   'list_id': 112824022,
#   'area_v2': 13096,
#   'apartment_feature': nan,
#   'landed_type': nan,
#   'street_id': nan,
#   'thumbnail_image': 'https://cdn.chotot.com/MSZ08bYPeOOJqDfCJBzVvjaF71-lZAgUPHuOF3pjrho/preset:listing/plain/bbd55d06ca58d49940df7fe58b351c9b-2857993845737569899.jpg',
#   'ad_id': 153384434,
#   'street_name': 'Nguyễn Đình Chiểu',
#   'account_name': 'Đỗ Kim Sơn',
#   'unitnumber': nan,
#   'projectid': nan,
#   'pty_characteristics': nan,
#   'furnishing_sell': nan,
#   'list_time': 1703497092000,
#   'price': 9000000000,
#   'category': 1020,
#   'price_string': '9 tỷ',
#   'latitude': 10.7854,
#   'protection_entitlement': False,
#   'category_name': 'Nhà ở',
#   'balconydirection': nan,
#   'area': 96,
#   'longitude': 106.6968}]
