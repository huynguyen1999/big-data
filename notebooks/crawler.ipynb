# %%
import asyncio
import aiohttp
import pandas as pd
import numpy as np
import sys
import time
pd.set_option('display.max_columns', None)

# %%
BASE_URL = "https://gateway.chotot.com/v1/public/ad-listing"
FILE_PATH = "../data/houses-for-sale.csv"
LIMIT = 100
REGIONS = [13000]  # Ho Chi Minh , Ha Noi
AREAS = [
    [
        13096,  # Q1
        13098,  # Q3
        13099,  # Q4
        13100,  # Q5
        13101,  # Q6
        13102,  # Q7
        13103,  # Q8
        13105,  # Q10
        13106,  # Q11
        13107,  # Q12
        13108,  # Binh Tan
        13109,  # Binh Thanh
        13110,  # Go Vap
        13111,  # Phu Nhuan
        13112,  # Tan Binh
        13113,  # Tan Phu
        13115,  # Binh Chanh
        13116,  # Cu Chi
        13117,  # Hoc Mon
        13118,  # Nha Be
        13119,  # TP Thu Duc
        13120,  # Can Gio
    ],
]
REGION_MAPPING = {
    13000: "Ho Chi Minh City",
}
AREA_MAPPING = {
    # Ho Chi Minh
    13000: {
        13096: "1st District",
        13098: "3rd District",
        13099: "4th District",
        13100: "5th District",
        13101: "6th District",
        13102: "7th District",
        13103: "8th District",
        13105: "10th District",
        13106: "11th District",
        13107: "12th District",
        13108: "Binh Tan District",
        13109: "Binh Thanh District",
        13110: "Go Vap District",
        13111: "Phu Nhuan District",
        13112: "Tan Binh District",
        13113: "Tan Phu District",
        13115: "Binh Chanh District",
        13116: "Cu Chi District",
        13117: "Hoc Mon District",
        13118: "Nha Be District",
        13119: "Thu Duc City",
        13120: "Can Gio District",
    },
}
CG_APARTMENT = "1010,1020"  # houses/apartments
STEP_SIZE = 10
DETAIL_STEP_SIZE = 100
MAX_RETRIES = 5
RETRY_INTERVAL = 2

# %%
def ordinal(number):
    if 10 <= number % 100 <= 20:
        suffix = "th"
    else:
        suffix = {1: "st", 2: "nd", 3: "rd"}.get(number % 10, "th")
    return str(number) + suffix

# %%
async def get_data_for_page(session, page, region, area, fetch_houses=True):
    url = f"{BASE_URL}?region_v2={region}&area_v2={area}&cg={CG_APARTMENT}&limit={LIMIT}&o={LIMIT * page}&st=s&page={page}&w=1&"
    for num_retrial in range(MAX_RETRIES):
        try:
            async with session.get((url)) as resp:
                data = await resp.json()
                return data["ads"] if fetch_houses else int(data["total"] / LIMIT) + 1
        except Exception as e:
            print(
                f"\t\tFETCH ERROR AT PAGE {page} ({ordinal(num_retrial+1)} time): {e}"
            )
        await asyncio.sleep(RETRY_INTERVAL)

    return None if fetch_houses else 0

# %%
async def get_data_in_batches():
    async with aiohttp.ClientSession() as session:
        houses = []
        for region, areas in zip(REGIONS, AREAS):
            print(f"Fetch houses from {REGION_MAPPING[region]}")
            for area in areas:
                total_pages = await get_data_for_page(
                    session, 0, region, area, fetch_houses=False
                )
                print(
                    f"\tFetch houses from {AREA_MAPPING[region][area]} ({total_pages} pages)"
                )
                for i in range(0, total_pages, STEP_SIZE):
                    print(
                        f"\t\t...fetching page {i} to {i + STEP_SIZE if i + STEP_SIZE < total_pages else total_pages}"
                    )
                    batch_tasks = [
                        get_data_for_page(session, page, region, area)
                        for page in range(i, i + STEP_SIZE)
                    ]
                    data_batch = await asyncio.gather(*batch_tasks)
                    houses.extend(data_batch)
        return houses

# %%
def flatten_recursive_np(lst):
    result = []
    for el in lst:
        if isinstance(el, list):
            result.extend(flatten_recursive_np(el))
        else:
            result.append(el)
    return np.array(result)

# %%
async def get_detail(session, house):
    url = f"{BASE_URL}/{house['list_id']}"
    for num_retrial in range(MAX_RETRIES):
        try:
            async with session.get((url)) as resp:
                if resp.status == 404: # not found
                    return house
                data = await resp.json()
                return data["ad"]
        except Exception as e:
            print(
                f"\t\tFETCH ERROR AT FOR HOUSE ID {id} ({ordinal(num_retrial+1)} time): {e}"
            )
        await asyncio.sleep(RETRY_INTERVAL)
    return None

# %%
async def get_detail_all_houses(houses):
    async with aiohttp.ClientSession() as session:
        detailed_houses = []
        for i in range(0, len(houses), DETAIL_STEP_SIZE):
            batch_tasks = [
                get_detail(session, house) for house in houses[i : i + DETAIL_STEP_SIZE]
            ]
            data_batch = await asyncio.gather(*batch_tasks)
            detailed_houses.extend(data_batch)

            # Print progress on the same line
            progress_percentage = (i + DETAIL_STEP_SIZE) / len(houses) * 100
            sys.stdout.write(f"\rProgress: {progress_percentage:.0f}%")
            sys.stdout.flush()
        print()
        return detailed_houses

# %%
houses = flatten_recursive_np(await get_data_in_batches())
houses = houses[houses != None]
# Out:
# Fetch houses from Ho Chi Minh City
# 	Fetch houses from 1st District (12 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 12
# 	Fetch houses from 3rd District (16 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 16
# 	Fetch houses from 4th District (8 pages)
# 		...fetching page 0 to 8
# 	Fetch houses from 5th District (8 pages)
# 		...fetching page 0 to 8
# 	Fetch houses from 6th District (12 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 12
# 	Fetch houses from 7th District (35 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 20
# 		FETCH ERROR AT PAGE 18 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13102&cg=1010,1020&limit=100&o=1800&st=s&page=18&w=1&')
# 		FETCH ERROR AT PAGE 10 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13102&cg=1010,1020&limit=100&o=1000&st=s&page=10&w=1&')
# 		FETCH ERROR AT PAGE 19 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13102&cg=1010,1020&limit=100&o=1900&st=s&page=19&w=1&')
# 		FETCH ERROR AT PAGE 10 (2nd time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13102&cg=1010,1020&limit=100&o=1000&st=s&page=10&w=1&')
# 		FETCH ERROR AT PAGE 19 (2nd time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13102&cg=1010,1020&limit=100&o=1900&st=s&page=19&w=1&')
# 		FETCH ERROR AT PAGE 18 (2nd time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13102&cg=1010,1020&limit=100&o=1800&st=s&page=18&w=1&')
# 		...fetching page 20 to 30
# 		...fetching page 30 to 35
# 	Fetch houses from 8th District (21 pages)
# 		...fetching page 0 to 10
# 		FETCH ERROR AT PAGE 9 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13103&cg=1010,1020&limit=100&o=900&st=s&page=9&w=1&')
# 		FETCH ERROR AT PAGE 6 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13103&cg=1010,1020&limit=100&o=600&st=s&page=6&w=1&')
# 		...fetching page 10 to 20
# 		...fetching page 20 to 21
# 	Fetch houses from 10th District (19 pages)
# 		...fetching page 0 to 10
# 		FETCH ERROR AT PAGE 2 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13105&cg=1010,1020&limit=100&o=200&st=s&page=2&w=1&')
# 		FETCH ERROR AT PAGE 6 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13105&cg=1010,1020&limit=100&o=600&st=s&page=6&w=1&')
# 		FETCH ERROR AT PAGE 5 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13105&cg=1010,1020&limit=100&o=500&st=s&page=5&w=1&')
# 		...fetching page 10 to 19
# 	Fetch houses from 11th District (10 pages)
# 		...fetching page 0 to 10
# 	Fetch houses from 12th District (37 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 20
# 		...fetching page 20 to 30
# 		...fetching page 30 to 37
# 	Fetch houses from Binh Tan District (48 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 20
# 		FETCH ERROR AT PAGE 11 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13108&cg=1010,1020&limit=100&o=1100&st=s&page=11&w=1&')
# 		...fetching page 20 to 30
# 		...fetching page 30 to 40
# 		...fetching page 40 to 48
# 		FETCH ERROR AT PAGE 46 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13108&cg=1010,1020&limit=100&o=4600&st=s&page=46&w=1&')
# 	Fetch houses from Binh Thanh District (32 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 20
# 		...fetching page 20 to 30
# 		...fetching page 30 to 32
# 	Fetch houses from Go Vap District (44 pages)
# 		...fetching page 0 to 10
# 		FETCH ERROR AT PAGE 0 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13110&cg=1010,1020&limit=100&o=0&st=s&page=0&w=1&')
# 		...fetching page 10 to 20
# 		...fetching page 20 to 30
# 		FETCH ERROR AT PAGE 28 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13110&cg=1010,1020&limit=100&o=2800&st=s&page=28&w=1&')
# 		...fetching page 30 to 40
# 		...fetching page 40 to 44
# 	Fetch houses from Phu Nhuan District (16 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 16
# 		FETCH ERROR AT PAGE 0 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13112&cg=1010,1020&limit=100&o=0&st=s&page=0&w=1&')
# 	Fetch houses from Tan Binh District (31 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 20
# 		...fetching page 20 to 30
# 		...fetching page 30 to 31
# 		FETCH ERROR AT PAGE 34 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13112&cg=1010,1020&limit=100&o=3400&st=s&page=34&w=1&')
# 	Fetch houses from Tan Phu District (37 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 20
# 		...fetching page 20 to 30
# 		...fetching page 30 to 37
# 	Fetch houses from Binh Chanh District (20 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 20
# 		FETCH ERROR AT PAGE 16 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13115&cg=1010,1020&limit=100&o=1600&st=s&page=16&w=1&')
# 		FETCH ERROR AT PAGE 12 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13115&cg=1010,1020&limit=100&o=1200&st=s&page=12&w=1&')
# 		FETCH ERROR AT PAGE 14 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13115&cg=1010,1020&limit=100&o=1400&st=s&page=14&w=1&')
# 		FETCH ERROR AT PAGE 19 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13115&cg=1010,1020&limit=100&o=1900&st=s&page=19&w=1&')
# 		FETCH ERROR AT PAGE 11 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13115&cg=1010,1020&limit=100&o=1100&st=s&page=11&w=1&')
# 	Fetch houses from Cu Chi District (5 pages)
# 		...fetching page 0 to 5
# 		FETCH ERROR AT PAGE 8 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13116&cg=1010,1020&limit=100&o=800&st=s&page=8&w=1&')
# 		FETCH ERROR AT PAGE 6 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13116&cg=1010,1020&limit=100&o=600&st=s&page=6&w=1&')
# 	Fetch houses from Hoc Mon District (15 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 15
# 	Fetch houses from Nha Be District (11 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 11
# 	Fetch houses from Thu Duc City (64 pages)
# 		...fetching page 0 to 10
# 		...fetching page 10 to 20
# 		FETCH ERROR AT PAGE 11 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=1100&st=s&page=11&w=1&')
# 		FETCH ERROR AT PAGE 12 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=1200&st=s&page=12&w=1&')
# 		FETCH ERROR AT PAGE 13 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=1300&st=s&page=13&w=1&')
# 		FETCH ERROR AT PAGE 17 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=1700&st=s&page=17&w=1&')
# 		FETCH ERROR AT PAGE 19 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=1900&st=s&page=19&w=1&')
# 		FETCH ERROR AT PAGE 16 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=1600&st=s&page=16&w=1&')
# 		...fetching page 20 to 30
# 		...fetching page 30 to 40
# 		...fetching page 40 to 50
# 		...fetching page 50 to 60
# 		FETCH ERROR AT PAGE 50 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=5000&st=s&page=50&w=1&')
# 		FETCH ERROR AT PAGE 52 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=5200&st=s&page=52&w=1&')
# 		FETCH ERROR AT PAGE 51 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=5100&st=s&page=51&w=1&')
# 		FETCH ERROR AT PAGE 57 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=5700&st=s&page=57&w=1&')
# 		FETCH ERROR AT PAGE 53 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=5300&st=s&page=53&w=1&')
# 		FETCH ERROR AT PAGE 59 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=5900&st=s&page=59&w=1&')
# 		FETCH ERROR AT PAGE 56 (1st time): 0, message='Attempt to decode JSON with unexpected mimetype: text/html; charset=utf-8', url=URL('https://gateway.chotot.com/v1/public/ad-listing?region_v2=13000&area_v2=13119&cg=1010,1020&limit=100&o=5600&st=s&page=56&w=1&')
# 		...fetching page 60 to 64
# 	Fetch houses from Can Gio District (1 pages)
# 		...fetching page 0 to 1

# %%
start_time = time.time()
detailed_houses = flatten_recursive_np(await get_detail_all_houses(houses))
elapsed_time = time.time() - start_time
print(f"Time consumed to fetch details of all houses: {elapsed_time} seconds")
# Out:
# Progress: 100%
# Time consumed to fetch details of all houses: 303.92775416374207 seconds

# %%
detailed_houses = detailed_houses[detailed_houses != None]
all_keys = set().union(*(d.keys() for d in detailed_houses))
# Create the DataFrame
df = pd.DataFrame.from_records(detailed_houses, columns=all_keys)
df = df[df['list_id'].duplicated() == False]

# %%
df.head()
# Out:
#   phone_hidden  apartment_type  escrow_can_deposit    ward  region  length  \
# 0          NaN             NaN                 2.0  9217.0      13    10.0
# 1          NaN             NaN                 2.0  9226.0      13    10.0
# 2          NaN             NaN                 2.0  9217.0      13     NaN
# 3          NaN             NaN                 2.0  9223.0      13     9.5
# 4          NaN             NaN                 2.0  9218.0      13     NaN
#
#    condition_ad                                     reviewer_image  \
# 0           NaN  https://static.chotot.com/thumbs/admin/9999999...
# 1           NaN  https://static.chotot.com/thumbs/admin/9999999...
# 2           NaN  https://static.chotot.com/thumbs/admin/9999999...
# 3           NaN  https://static.chotot.com/thumbs/admin/9999999...
# 4           NaN  https://static.chotot.com/thumbs/admin/9999999...
#
#         phone                       account_oid  number_of_images  floors  \
# 0  092766****  401d3a2722b3029a60f2d06321874778               9.0     3.0
# 1  093366****  2ba33655e496616002ec75c20ddaf5e8               6.0     2.0
# 2  058518****  1ac98311a851b61e093d13cdf1f2de33               4.0     NaN
# 3  090187****  0ab288b7de0724988a0631cf314d5d28               6.0     NaN
# 4  090135****  b85c01229386d78863ff719ae27e0018               3.0     NaN
#
#   label_campaigns has_video address payment_delivery type  size  zero_deposit  \
# 0            None       NaN     NaN              NaN    s  32.0         False
# 1            None       NaN     NaN              NaN    s  30.0         False
# 2            None       NaN     NaN              NaN    s  10.0         False
# 3            None       NaN     NaN              NaN    s  33.0         False
# 4            None       NaN     NaN              NaN    s  17.0         False
#
#   project_oid                                         webp_image  \
# 0         NaN  https://cdn.chotot.com/Vdo81ZRCsR_OctWMywFZr3h...
# 1         NaN  https://cdn.chotot.com/lwpW1gYbubNF-m7uz7RkWpS...
# 2         NaN  https://cdn.chotot.com/Euh85xletv0yyh10Oj003uI...
# 3         NaN  https://cdn.chotot.com/dgff7XRz_GSDb-BbIsRg8ey...
# 4         NaN  https://cdn.chotot.com/WqEmMlKkfx2YWphvkPfBdVC...
#
#    contain_videos  living_size                                avatar  \
# 0             2.0         90.0  https://cdn.chotot.com/uac2/15097873
# 1             2.0         70.0   https://cdn.chotot.com/uac2/1264592
# 2             2.0          NaN  https://cdn.chotot.com/uac2/26372279
# 3             2.0          NaN  https://cdn.chotot.com/uac2/26182525
# 4             2.0        103.0  https://cdn.chotot.com/uac2/17667771
#
#    property_status area_name videos  region_v2  house_type  owner  rooms  \
# 0              NaN    Quận 1     []      13000         3.0  False      3
# 1              NaN    Quận 1     []      13000         3.0  False      2
# 2              NaN    Quận 1     []      13000         3.0  False      4
# 3              NaN    Quận 1     []      13000         3.0  False      3
# 4              NaN    Quận 1     []      13000         1.0  False      4
#
#    property_back_condition                                             images  \
# 0                      NaN  [https://cdn.chotot.com/e2KeIxUm3uXx4-PhCOl-o1...
# 1                      NaN  [https://cdn.chotot.com/luF_zbn5o6NS1iX0Fhrqe3...
# 2                      NaN  [https://cdn.chotot.com/bioAQPE4HDyOf9AOXkwkuS...
# 3                      NaN  [https://cdn.chotot.com/QM1co-cGTvQn8iS7h4RQtp...
# 4                      NaN  [https://cdn.chotot.com/Wwav0GSz0thp1zhcP56Ftr...
#
#   shop_alias  unitnumber_display image company_logo     state block  \
# 0        NaN                 NaN   NaN          NaN  accepted   NaN
# 1        NaN                 NaN   NaN          NaN  accepted   NaN
# 2        NaN                 NaN   NaN          NaN  accepted   NaN
# 3        NaN                 NaN   NaN          NaN  accepted   NaN
# 4        NaN                 NaN   NaN          NaN  accepted   NaN
#
#    pty_map_modifier                                               body  \
# 0            0.0008  Chính chủ cần bán gấp nhà đường Thạch Thị Than...
# 1            0.0008  📌 BÁN NHÀ Quận 1- Nguyễn Văn Cừ, P.Cầu Kho, Q1...
# 2            0.0008  Diện tích: 40m2\nGiá bán: 1 tỷ 468\nKết cấu: 1...
# 3            0.0008  Giá cực tốt, cần tiền bán gấp nhà Đề Thám, Phư...
# 4            0.0008  chính chủ Bán nhà MT Nguyễn Đình Chiểu, Q.1\n3...
#
#    toilets street_number  floornumber     region_name  \
# 0      4.0           NaN          NaN  Tp Hồ Chí Minh
# 1      1.0           NaN          NaN  Tp Hồ Chí Minh
# 2      NaN           NaN          NaN  Tp Hồ Chí Minh
# 3      4.0           NaN          NaN  Tp Hồ Chí Minh
# 4      5.0           NaN          NaN  Tp Hồ Chí Minh
#
#                                              pty_map shop  \
# 0  https://cdn.chotot.com/admincentre/location/10...  NaN
# 1  https://cdn.chotot.com/admincentre/location/10...  NaN
# 2  https://cdn.chotot.com/admincentre/location/10...  NaN
# 3  https://cdn.chotot.com/admincentre/location/10...  NaN
# 4  https://cdn.chotot.com/admincentre/location/10...  NaN
#
#    property_road_condition ad_labels  account_id  property_legal_document  \
# 0                      NaN      None    15097873                      1.0
# 1                      NaN      None     1264592                      1.0
# 2                      NaN      None    26372279                      NaN
# 3                      NaN      None    26182525                      1.0
# 4                      NaN      None    17667771                      NaN
#
#             date              location type_name            ward_name  \
# 0  19 phút trước       10.7901,106.693   Cần bán      Phường Tân Định
# 1  20 phút trước      10.7538,106.6872   Cần bán       Phường Cầu Kho
# 2  35 phút trước      10.7917,106.6931   Cần bán      Phường Tân Định
# 3  55 phút trước  10.763212,106.695915   Cần bán  Phường Cầu Ông Lãnh
# 4  59 phút trước      10.7854,106.6968   Cần bán        Phường Đa Kao
#
#                                              subject  direction  \
# 0  Nhà Q1, Thạch Thị Thanh, 3L, full Nội Thất đẹp...        NaN
# 1                  bán nhà nhìn ra cầu nguyễn văn cừ        6.0
# 2  ĐÁY BẮT GIÁ bán nhà Nguyễn Phi Khanh Q.1 1T2L ...        NaN
# 3  Chính chủ cần bán gấp nhà Đề Thám, Quận 1. Giá...        NaN
# 4  Chính chủ bán nhà Ngang 3m MT Nguyễn Đình Chiể...        1.0
#
#    streetnumber_display pty_jupiter  company_ad  price_million_per_m2  \
# 0                   NaN           0        True            184.375000
# 1                   NaN           0        True            183.333333
# 2                   NaN           0        True            146.800000
# 3                   NaN           0        True            103.030303
# 4                   NaN           0        True            529.411765
#
#   reviewer_nickname detail_address  width    list_id  area_v2  \
# 0        Trần Thanh            NaN    3.2  112718747    13096
# 1          An Nhiên  Trần Hưng Ðạo    3.0  112642233    13096
# 2           Bình An            NaN    NaN  112824656    13096
# 3          Tuấn Anh            NaN    3.5  111661713    13096
# 4          Minh Tri            NaN    NaN  112824022    13096
#
#    apartment_feature  landed_type  street_id  \
# 0                NaN          NaN        NaN
# 1                NaN          NaN        NaN
# 2                NaN          NaN        NaN
# 3                NaN          NaN        NaN
# 4                NaN          NaN        NaN
#
#                                      thumbnail_image      ad_id  \
# 0  https://cdn.chotot.com/kKpv7Li0ECMHvkXpoD2gihz...  153261936
# 1  https://cdn.chotot.com/7TQhv1Jsfx9ym50yVnUg4xw...  153172868
# 2  https://cdn.chotot.com/Diwx3L28MI5zFdsAEvYfoyi...  153385154
# 3  https://cdn.chotot.com/_1N7QNHhsWtUlfVm3Yv7cnE...  152029634
# 4  https://cdn.chotot.com/MSZ08bYPeOOJqDfCJBzVvja...  153384434
#
#              street_name account_name unitnumber  projectid  \
# 0  Đường Thạch Thị Thanh    Trần Ngọc        NaN        NaN
# 1      Đường Võ Văn Kiệt       Phương        NaN        NaN
# 2       Nguyễn Phi Khanh     Ngọc Ánh        NaN        NaN
# 3                Đề Thám  Võ Minh Thư        NaN        NaN
# 4      Nguyễn Đình Chiểu   Đỗ Kim Sơn        NaN        NaN
#
#   pty_characteristics  furnishing_sell      list_time       price  category  \
# 0                 NaN              1.0  1703499530998  5900000000      1020
# 1                 [2]              NaN  1703499439901  5500000000      1020
# 2                 NaN              NaN  1703498571000  1468000000      1020
# 3                 [2]              1.0  1703497352000  3400000000      1020
# 4                 NaN              NaN  1703497092000  9000000000      1020
#
#   price_string   latitude  protection_entitlement category_name  \
# 0       5,9 tỷ  10.790100                   False         Nhà ở
# 1       5,5 tỷ  10.753800                   False         Nhà ở
# 2     1,468 tỷ  10.791700                   False         Nhà ở
# 3       3,4 tỷ  10.763212                   False         Nhà ở
# 4         9 tỷ  10.785400                   False         Nhà ở
#
#    balconydirection  area   longitude
# 0               NaN    96  106.693000
# 1               NaN    96  106.687200
# 2               NaN    96  106.693100
# 3               NaN    96  106.695915
# 4               NaN    96  106.696800

# %%
df.to_csv(FILE_PATH, index=False)
